# %%
import numpy as np
import matplotlib
import cv2
import matplotlib.pyplot as plt
import math
import pylab

# %%
plt.imshow(cv2.imread("23.jpg"))

# %%
#0
plt.style.use("seaborn-dark")
fig,axs=plt.subplots(2,3,figsize=(10,7))
axs[0,0].xaxis.set_ticklabels([])
axs[0,0].yaxis.set_ticklabels([])
axs[0,1].xaxis.set_ticklabels([])
axs[0,1].yaxis.set_ticklabels([])
axs[0,2].xaxis.set_ticklabels([])
axs[0,2].yaxis.set_ticklabels([])
axs[1,0].xaxis.set_ticklabels([])
axs[1,0].yaxis.set_ticklabels([])
axs[1,1].xaxis.set_ticklabels([])
axs[1,1].yaxis.set_ticklabels([])
axs[1,2].xaxis.set_ticklabels([])
axs[1,2].yaxis.set_ticklabels([])
pylab.text(-360.0,50.0,"Best Fans Here", size = 15, weight="bold")
pylab.text(-360.0,15.0,"Vegan Power", size = 15, weight="bold")
pylab.text(-360.0,-3,"Proud to be BLACK", size = 15, weight="bold")
pylab.text(-360.0,-41.0,"The BLESSED One", size = 15, weight="bold")
pylab.text(110,7,"Get In There,Mr L", size = 15, weight="bold")
#1
axs[0,0].plot(np.random.normal(size=100)*0.6, color='black')
shape,scale =5,3
S1=[((i-5)**(4))*0.025+6+np.random.normal(1) for i in range(0,6)]+[((i-5)**6)*0.27+6+np.random.normal(1) for i in range(6,8)]+[(-0.04)*i+27.48+np.random.normal(1)  for i in range (9,100)]
axs[0,0].plot(S1, color="black")
#2
axs[0,1].plot(np.random.normal(size=100)*0.6, color='black')
shape,scale =5,3
S2=[((i-5)**(4))*0.025+6-np.random.normal(1) for i in range(0,6)]+[((i-5)**6)*0.27+6-np.random.normal(1) for i in range(6,8)]+[(-0.1)*i+27.48+np.random.normal(3)  for i in range (9,100)]
axs[0,1].plot(S2, color="black")
axs[0,1].plot([33])
#3
axs[0,2].plot(np.random.normal(size=100)*0.6, color='black')
shape,scale =5,3
S3=[((i-5)**(4))*0.025+6+np.random.normal(1) for i in range(0,6)]+[((i-5)**6)*0.27+6+np.random.normal(1) for i in range(6,8)]+[(-0.12)*i+27.48+np.random.normal(1)  for i in range (9,100)]
axs[0,2].plot(S3, color="black")
axs[0,2].plot([40])
#4
axs[1,0].plot(np.random.normal(size=100)*0.3, color='black')
shape,scale =5,3
S4=[(-5)*i-5+np.random.normal(2) for i in range(8)]+[11.28*np.log(i)-62 + np.random.normal(1) for i in range (8,100)]
axs[1,0].plot(S4, color="black")
#5
axs[1,1].plot(np.random.normal(size=100)*0.3, color='black')
shape,scale =5,3
S5=[(-5)*i-5+np.random.normal(2) for i in range(8)]+[11.28*np.log(i)-66 + np.random.normal(1) for i in range (8,100)]
axs[1,1].plot(S5, color="black")
axs[1,1].plot([-55])
#6
axs[1,2].plot(np.random.normal(size=100)*0.3, color='black')
shape,scale =5,3
S6=[((-5)*i-5)//2+np.random.normal(2) for i in range(8)]+[(11.28*np.log(i)-70)//2 + np.random.normal(1) for i in range (8,100)]
axs[1,2].plot(S6, color="black")
axs[1,2].plot([-40])
plt.show()
